# %%
temperature=[22,25,19,23,26,20,21,22]
print (temperature[0])
print (temperature[-1])
temperature.insert(0,24)
print (temperature)
temperature.remove(19)
print (temperature)
print (len (temperature))
print (sum (temperature))
print (max (temperature))
# Out:
# 22
# 22
# [24, 22, 25, 19, 23, 26, 20, 21, 22]
# [24, 22, 25, 23, 26, 20, 21, 22]
# 8
# 183
# 26

# %%
Student = {
    "name": "Yaroslav",
    "age" : 28,
    "city" : "Kropyvnytskyi"
}
Student.get("name")
# Out:
# 'Yaroslav'

# %%
Student ["age"]=21
print (Student["age"])
# Out:
# 21

# %%
Student ["hobby"]="programming"
print (Student)
# Out:
# {'name': 'Yaroslav', 'age': 21, 'city': 'Kropyvnytskyi', 'hobby': 'programming'}

# %%
print (Student.keys())
# Out:
# dict_keys(['name', 'age', 'city', 'hobby'])

# %%
print (Student.values())
# Out:
# dict_values(['Yaroslav', 21, 'Kropyvnytskyi', 'programming'])
