# %%
counter = -3
while counter <=5:
    print(f"Answer: {counter}")
    counter +=1
# Out:
# Answer: -3
# Answer: -2
# Answer: -1
# Answer: 0
# Answer: 1
# Answer: 2
# Answer: 3
# Answer: 4
# Answer: 5

# %%
numbers = [11, 4, 9, 16, 7, 5]
squares = [n**2 for n in numbers]
even_numbers = [n for n in numbers if n % 2 == 0]
times_ten = [n * 10 for n in numbers]
print("Squares:", squares)
print("Even numbers:", even_numbers)
print("Times ten:", times_ten)
# Out:
# Squares: [121, 16, 81, 256, 49, 25]
# Even numbers: [4, 16]
# Times ten: [110, 40, 90, 160, 70, 50]

# %%
numbers = list  (range(1, 11))
result = [n*2 if n % 2 == 0 else n-1 for n in numbers]
print(result)
# Out:
# [0, 4, 2, 8, 4, 12, 6, 16, 8, 20]
