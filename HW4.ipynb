# %%
numbers = [1,2,3,4,5,6,7]
for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
names = ["Олег", "Анна", "Іван", "Марія"]
for name in names:
    print(f'Привіт, {name}!')
# Out:
# Привіт, Олег!
# Привіт, Анна!
# Привіт, Іван!
# Привіт, Марія!

# %%
grade = [85, 90, 78, 92, 88]
for i in enumerate(grade):
    print (f'Студент {i[0]+1}: {grade[i[0]]} балів')
# Out:
# Студент 1: 85 балів
# Студент 2: 90 балів
# Студент 3: 78 балів
# Студент 4: 92 балів
# Студент 5: 88 балів

# %%
сумма = 0
for x in range(1,21):
     if x % 2 == 0:
            сумма += x
print(сумма)
# Out:
# 110
