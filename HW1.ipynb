# %%
name='Yaroslav'
age=28
height=192.5
is_student=True
print(f'({name},{age},{height},{is_student})')
# Out:
# (Yaroslav,28,192.5,True)

# %%
var1=15
var2=4
print ((var1+var2), (var1-var2), (var1*var2), (var1/var2), (var1//var2), (var1%var2), (var1**var2))
# Out:
# 19 11 60 3.75 3 3 50625

# %%
last_name='Kozachenko'
full_name=name +" "+ last_name
print (full_name)
print (full_name.upper())
print (full_name.lower())
print (len(full_name))
print (f'(My name is {full_name}, I am {age} years old)')
# Out:
# Yaroslav Kozachenko
# YAROSLAV KOZACHENKO
# yaroslav kozachenko
# 19
# (My name is Yaroslav Kozachenko, I am 28 years old)
